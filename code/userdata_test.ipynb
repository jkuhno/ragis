# %%
from azure.identity import ClientSecretCredential
from azure.identity import DefaultAzureCredential
from msgraph import GraphServiceClient
from msgraph.generated.users.item.user_item_request_builder import UserItemRequestBuilder
from kiota_abstractions.base_request_configuration import RequestConfiguration
import pandas as pd

credential = DefaultAzureCredential()
client = GraphServiceClient(credential)

scopes = ['https://graph.microsoft.com/.default']
graph_client = GraphServiceClient(credential, scopes)

# %%
# Get all Entra ID users
query_params = UserItemRequestBuilder.UserItemRequestBuilderGetQueryParameters(
    select=['userPrincipalName','displayName','givenName','surname','jobTitle','department','usageLocation','accountEnabled','state','country','createdDateTime']
)

config = RequestConfiguration(
    query_parameters=query_params
)

users = await graph_client.users.get(config)

# %%
# Filter out none values from users
users.value[0].user_principal_name

user_list = []
for user in users.value:
    x = {
        'userPrincipalName': user.user_principal_name,
        'displayName': user.display_name,
        'givenName': user.given_name,
        'surname': user.surname,
        'jobTitle': user.job_title,
        'department': user.department,
        'usageLocation': user.usage_location,
        'accountEnabled': user.account_enabled,
        'state': user.state,
        'country': user.country,
        'createdDateTime': user.created_date_time
    }
    user_list.append(x)

# %%
# Create a data frame from the users list
pd.DataFrame(user_list)
# Out:
#                                    userPrincipalName         displayName  \
# 0               amelie@kuhnojkagmail.onmicrosoft.com       Amélie Dupont
# 1                 bill@kuhnojkagmail.onmicrosoft.com          Bill Hader
# 2               emilia@kuhnojkagmail.onmicrosoft.com  Emilia Hartikainen
# 3                 joel@kuhnojkagmail.onmicrosoft.com         Joel Kataja
# 4  kuhnojka_gmail.com#EXT#@kuhnojkagmail.onmicros...          Jani Kuhno
# 5                lauri@kuhnojkagmail.onmicrosoft.com      Lauri Virtanen
#
#   givenName      surname                          jobTitle  \
# 0    Amélie       Dupont  Marketing Coordinator (EXTERNAL)
# 1      Bill        Hader      Senior Consultant (EXTERNAL)
# 2    Emilia  Hartikainen               Senior Data Analyst
# 3      None         None                              None
# 4      Jani        Kuhno                              None
# 5     Lauri     Virtanen             IT Support Specialist
#
#                department usageLocation  accountEnabled     state country  \
# 0       Digital Marketing            FR            True     Paris      FR
# 1                    None            US            True  New York     USA
# 2   Business Intelligence            FI            True  Helsinki      FI
# 3                    None            FI            True      None      FI
# 4                    None            FI            True      None    None
# 5  Information Technology            FI            True     Espoo      FI
#
#             createdDateTime
# 0 2024-09-20 18:53:03+00:00
# 1 2024-09-13 18:45:55+00:00
# 2 2024-09-20 18:53:03+00:00
# 3 2024-09-12 20:17:21+00:00
# 4 2024-09-12 19:37:04+00:00
# 5 2024-09-20 18:53:03+00:00

# %%
async def get_users(data_type):
    credential = DefaultAzureCredential()
    client = GraphServiceClient(credential)
    
    scopes = ['https://graph.microsoft.com/.default']
    graph_client = GraphServiceClient(credential, scopes)
    
    # Get all Entra ID users
    
    config = RequestConfiguration(
        query_parameters=query_params
    )
    
    users = await graph_client.users.get(config)
    
    user_list = []
    for user in users.value:
        x = {
            'userPrincipalName': user.user_principal_name,
            'displayName': user.display_name,
            'givenName': user.given_name,
            'surname': user.surname,
            'jobTitle': user.job_title,
            'department': user.department,
            'usageLocation': user.usage_location,
            'accountEnabled': user.account_enabled,
            'state': user.state,
            'country': user.country,
            'createdDateTime': user.created_date_time
        }
        user_list.append(x)
    
    user_df = pd.DataFrame(user_list)
    if data_type == "csv":
        user_df.to_csv("/data/tmp/azure_users")
        return await ["/data/tmp/azure_users"]

    return user_df

# %%
import asyncio

# %%
asyncio.run(get_users("csv"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 asyncio.run(get_users("csv"))
#
# File /usr/lib/python3.10/asyncio/runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
csvs
# Out:
# <coroutine object get_users at 0x7f5cf4ef1bd0>
